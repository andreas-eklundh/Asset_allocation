# %%
import pandas as pd

# %%
a = pd.read_csv('Data_clean\FF_cleaned.csv')
b = pd.read_csv('Data_clean\bond_returns.csv')
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\F'
# <>:1: SyntaxWarning: invalid escape sequence '\F'
# C:\Users\chris\AppData\Local\Temp\ipykernel_10656\229917904.py:1: SyntaxWarning: invalid escape sequence '\F'
#   a = pd.read_csv('Data_clean\FF_cleaned.csv')
# C:\Users\chris\AppData\Local\Temp\ipykernel_10656\229917904.py:1: SyntaxWarning: invalid escape sequence '\F'
#   a = pd.read_csv('Data_clean\FF_cleaned.csv')
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[5], line 2
#       1 a = pd.read_csv('Data_clean\FF_cleaned.csv')
# ----> 2 b = pd.read_csv('Data_clean\bond_returns.csv')
#
# ...

# %%
# Out:
#             Date  Mkt-RF   SMB   HML    RF
# 0     1927-01-31   -0.06 -0.37  4.54  0.25
# 1     1927-02-28    4.18  0.04  2.94  0.26
# 2     1927-03-31    0.13 -1.65 -2.61  0.30
# 3     1927-04-30    0.46  0.30  0.81  0.25
# 4     1927-05-31    5.44  1.53  4.73  0.30
# ...          ...     ...   ...   ...   ...
# 1159  2023-08-31   -2.39 -3.20 -1.08  0.45
# 1160  2023-09-30   -5.24 -2.49  1.45  0.43
# 1161  2023-10-31   -3.18 -3.88  0.19  0.47
# 1162  2023-11-30    8.83 -0.03  1.66  0.44
# 1163  2023-12-31    4.87  6.36  4.92  0.43
#
# [1164 rows x 5 columns]
